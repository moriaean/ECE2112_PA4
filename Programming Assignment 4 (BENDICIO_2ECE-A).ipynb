# %% [markdown]
# # SEDRIC LANCE B. BENDICIO

# %% [markdown]
# ### 2 ECE - A

# %% [markdown]
# ## EXPERIMENT 4: DATA WRANGLING AND DATA VISUALIZATION

# %% [markdown]
# #### INITIALIZATIONS

# %%
import pandas as pd
import matplotlib.pyplot as plt

ECE_BE_2 = pd.read_csv('board2.csv')

# %%
ECE_BE_2
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# 13  S14  Female  Microelectronics     Luzon    83           77    89
# 14  S15  Female  Microelectronics  Mindanao    69           41    40
# 15  S16  Female     Communication     Luzon    71           70    87
# 16  S17  Female  Microelectronics  Mindanao    81           79    77
# 17  S18    Male     Communication   Visayas    81           40    81
# 18  S19    Male  Microelectronics     Luzon    79           63    79
# 19  S20  Female     Communication  Mindanao    59           60    62
# 20  S21  Female  Microelectronics   Visayas    83           51    68
# 21  S22  Female     Communication   Visayas    64           39    89
# 22  S23    Male   Instrumentation     Luzon    84           70    74
# 23  S24  Female  Microelectronics   Visayas    85           45    60
# 24  S25    Male     Communication     Luzon    74           91    94
# 25  S26  Female   Instrumentation   Visayas    71           47    83
# 26  S27    Male  Microelectronics   Visayas    70           47    40
# 27  S28    Male     Communication   Visayas    85           53    80
# 28  S29    Male   Instrumentation  Mindanao    73           48    71
# 29  S30    Male   Instrumentation     Luzon    78           81    57
#
#     Communication
# 0              78
# 1              52
# 2              57
# 3              68
# 4              88
# 5              83
# 6              48
# 7              53
# 8              42
# 9              44
# 10             67
# 11             64
# 12             43
# 13             73
# 14             86
# 15             81
# 16             45
# 17             52
# 18             71
# 19             85
# 20             72
# 21             58
# 22             47
# 23             41
# 24             42
# 25             62
# 26             86
# 27             53
# 28             62
# 29             56

# %% [markdown]
# #### AVERAGE

# %%
ECE_BE_2 ['Average'] = ((ECE_BE_2.Math + ECE_BE_2.Electronics + ECE_BE_2.GEAS + ECE_BE_2.Communication)/4)
ECE_BE_2['Average']
# Out:
# 0     75.00
# 1     67.25
# 2     72.75
# 3     70.50
# 4     69.00
# 5     75.50
# 6     58.50
# 7     61.75
# 8     47.75
# 9     67.25
# 10    54.75
# 11    76.00
# 12    62.25
# 13    80.50
# 14    59.00
# 15    77.25
# 16    70.50
# 17    63.50
# 18    73.00
# 19    66.50
# 20    68.50
# 21    62.50
# 22    68.75
# 23    57.75
# 24    75.25
# 25    65.75
# 26    60.75
# 27    67.75
# 28    63.50
# 29    68.00
# Name: Average, dtype: float64

# %% [markdown]
# #### A. POSITIONAL AND LABEL-BASED SLICING

# %%
VisComm = ECE_BE_2[
            (ECE_BE_2['Hometown'] == 'Visayas') & 
             (ECE_BE_2['Track'] == 'Communication')
             ][['Name', 'Gender', 'Math', 'Electronics', 'Average']]

display (VisComm)

print ("Number of rows:", len (VisComm))
# Out:
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56    54.75
# 11  S12    Male    89           67    76.00
# 17  S18    Male    81           40    63.50
# 21  S22  Female    64           39    62.50
# 27  S28    Male    85           53    67.75
# Number of rows: 5

# %% [markdown]
# #### B. VISAYAS FEMALE DATAFRAME

# %%
ECE_BE_2 ['Average'] = ((ECE_BE_2.Math + ECE_BE_2.Electronics + ECE_BE_2.GEAS + ECE_BE_2.Communication)/4)
VisFemale = ECE_BE_2[
            (ECE_BE_2['Hometown'] == 'Visayas') & 
             (ECE_BE_2['Gender'] == 'Female')
             ][['Name', 'Track', 'GEAS', 'Electronics', 'Average']]


print ("\n\033[1m" + "\t    Female Takers from Visayas" + "\033[0m")
display (VisFemale)
print ("Number of rows:", len (VisFemale))

print ("\n\033[1m" + "Female Takers from Visayas with Greater than 60 Average" + "\033[0m")
display (VisFemale[VisFemale['Average'] >= 60])
print ("Number of rows:", len (VisFemale[VisFemale['Average'] >= 60]))
# Out:
# 	    Female Takers from Visayas
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 10  S11     Communication    48           56    54.75
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 23  S24  Microelectronics    60           45    57.75
# 25  S26   Instrumentation    83           47    65.75
# Number of rows: 6
#
# Female Takers from Visayas with Greater than 60 Average
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 25  S26   Instrumentation    83           47    65.75
# Number of rows: 4

# %% [markdown]
# #### C. CATEGORY-AVERAGE VISUALIZATION

# %% [markdown]
# ##### a. Mean Average by Track, by Gender, and by Hometown

# %%
mean_track = pd.DataFrame(ECE_BE_2.groupby(['Track'])['Average'].mean().reset_index())

mean_gender = pd.DataFrame(ECE_BE_2.groupby(['Gender'])['Average'].mean().reset_index())

mean_hometown = pd.DataFrame(ECE_BE_2.groupby(['Hometown'])['Average'].mean().reset_index())

# %% [markdown]
# ##### b. Summary tables of Mean Average by Track, by Gender, and by Hometown

# %%
print("\n\033[1m" + "Mean Average by Track" + "\033[0m\n")
display(mean_track)

print("\n\033[1m" + "Mean Average by Gender" + "\033[0m\n")
display(mean_gender)

print("\n\033[1m" + "Mean Average by Hometown" + "\033[0m\n")
display(mean_hometown)
# Out:
# Mean Average by Track
#               Track  Average
# 0     Communication   67.975
# 1   Instrumentation   65.225
# 2  Microelectronics   67.500
# Mean Average by Gender
#    Gender    Average
# 0  Female  66.616667
# 1    Male  67.183333
# Mean Average by Hometown
#    Hometown    Average
# 0     Luzon  68.083333
# 1  Mindanao  66.678571
# 2   Visayas  65.750000

# %% [markdown]
# ##### c. Summary tables of Mean Average by Track, by Gender, and by Hometown

# %%
plt.figure(figsize=(20, 8))
plt.ylim(0, 100)
plt.title("Mean Average by Track                                                          Mean Average by Gender                                                    Mean Average by Hometown")
mean_track_graph = plt.bar(mean_track['Track'], mean_track['Average'])
plt.bar_label(mean_track_graph, label_type='edge')

mean_gender_graph = plt.bar(mean_gender['Gender'], mean_gender['Average'])
plt.bar_label(mean_gender_graph, label_type='edge')

mean_hometown_graph = plt.bar(mean_hometown['Hometown'], mean_hometown['Average'])
plt.bar_label(mean_hometown_graph, label_type='edge')
# Out:
# [Text(0, 0, '68.0833'), Text(0, 0, '66.6786'), Text(0, 0, '65.75')]

# %% [markdown]
# ##### d. Summary tables of Mean Average by Track, by Gender, and by Hometown

# %% [markdown]
# Track: The Communication track achieved the highest sample mean average among all tracks at 67.975.
#
# Gender: Male students recorded the highest sample mean average overall at 67.1833.
#
# Hometown: Students originating from Luzon held the highest sample mean average across all regions at 68.0833.
